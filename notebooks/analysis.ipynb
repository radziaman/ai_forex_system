# %% [markdown]
# # AI Forex Trading System - Analysis Notebook
#
# This notebook provides interactive analysis of the AI forex trading system.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..') / 'src'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from ai_forex_system.data import DataFetcher, DataPreprocessor
from ai_forex_system.features import FeatureEngineer
from ai_forex_system.model import LSTMCNNHybrid
from ai_forex_system.backtest import BacktestEngine
from ai_forex_system.risk import RiskManager

print('AI Forex Trading System loaded successfully!')

# %%
# Fetch sample data
fetcher = DataFetcher(source='yfinance')
print('Fetching EURUSD data...')
# df = fetcher.fetch_ohlcv('EURUSD=X', '1h', '2024-01-01')
# print(f'Data shape: {df.shape}')
# df.head()

# %%
# Feature engineering example
# fe = FeatureEngineer(lookback=30)
# df_features = fe.generate_all_features(df)
# print(f'Features generated: {len(df_features.columns)}')
# df_features.describe()

# %%
# Visualize features
# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# axes[0,0].plot(df_features.index[-100:], df_features['close'][-100:])
# axes[0,0].set_title('Close Price')
# axes[0,1].plot(df_features.index[-100:], df_features['rsi_14'][-100:])
# axes[0,1].set_title('RSI 14')
# axes[1,0].plot(df_features.index[-100:], df_features['atr_14'][-100:])
# axes[1,0].set_title('ATR 14')
# axes[1,1].plot(df_features.index[-100:], df_features['vol_regime'][-100:])
# axes[1,1].set_title('Volatility Regime')
# plt.tight_layout()
# plt.show()
